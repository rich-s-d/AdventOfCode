# %%
ans = {}

# %%
print(type(ans))
# Out:
# <class 'dict'>

# %%
f = open('day10.txt', 'r')
adapters = list(map(int, f.read().split('\n')))
adapters.sort()
adapters = adapters + [max(adapters) + 3]

adapters
# Out:
# [1,
#  2,
#  3,
#  4,
#  7,
#  8,
#  9,
#  10,
#  13,
#  16,
#  17,
#  18,
#  19,
#  20,
#  23,
#  26,
#  29,
#  30,
#  31,
#  32,
#  35,
#  38,
#  39,
#  40,
#  41,
#  44,
#  45,
#  46,
#  47,
#  50,
#  51,
#  52,
#  53,
#  54,
#  57,
#  58,
#  61,
#  64,
#  65,
#  66,
#  67,
#  68,
#  71,
#  72,
#  73,
#  74,
#  75,
#  78,
#  79,
#  80,
#  83,
#  84,
#  85,
#  86,
#  87,
#  90,
#  91,
#  92,
#  93,
#  94,
#  97,
#  98,
#  99,
#  100,
#  103,
#  104,
#  105,
#  108,
#  111,
#  112,
#  113,
#  114,
#  115,
#  118,
#  119,
#  122,
#  125,
#  126,
#  127,
#  128,
#  131,
#  132,
#  133,
#  134,
#  135,
#  138,
#  139,
#  140,
#  141,
#  142,
#  145,
#  146,
#  147,
#  150,
#  153]

# %%
ans = {}
ans[0] = 1
for a in adapters:
    print(a)
    ans[a] = ans.get(a - 1, 0) + ans.get(a - 2, 0) + ans.get(a - 3, 0)
    print(ans)

print(f'Answer: {ans[adapters[-1]]}')
# Out:
# 1
# {0: 1, 1: 1}
# 2
# {0: 1, 1: 1, 2: 2}
# 3
# {0: 1, 1: 1, 2: 2, 3: 4}
# 4
# {0: 1, 1: 1, 2: 2, 3: 4, 4: 7}
# 7
# {0: 1, 1: 1, 2: 2, 3: 4, 4: 7, 7: 7}
# 8
# {0: 1, 1: 1, 2: 2, 3: 4, 4: 7, 7: 7, 8: 7}
# 9
# {0: 1, 1: 1, 2: 2, 3: 4, 4: 7, 7: 7, 8: 7, 9: 14}
# 10
# {0: 1, 1: 1, 2: 2, 3: 4, 4: 7, 7: 7, 8: 7, 9: 14, 10: 28}
# 13
# {0: 1, 1: 1, 2: 2, 3: 4, 4: 7, 7: 7, 8: 7, 9: 14, 10: 28, 13: 28}
# 16
# {0: 1, 1: 1, 2: 2, 3: 4, 4: 7, 7: 7, 8: 7, 9: 14, 10: 28, 13: 28, 16: 28}
# 17
# {0: 1, 1: 1, 2: 2, 3: 4, 4: 7, 7: 7, 8: 7, 9: 14, 10: 28, 13: 28, 16: 28, 17: 28}
# 18
# {0: 1, 1: 1, 2: 2, 3: 4, 4: 7, 7: 7, 8: 7, 9: 14, 10: 28, 13: 28, 16: 28, 17: 28, 18: 56}
# 19
# {0: 1, 1: 1, 2: 2, 3: 4, 4: 7, 7: 7, 8: 7, 9: 14, 10: 28, 13: 28, 16: 28, 17: 28, 18: 56, 19: 112}
# 20
# {0: 1, 1: 1, 2: 2, 3: 4, 4: 7, 7: 7, 8: 7, 9: 14, 10: 28, 13: 28, 16: 28, 17: 28, 18: 56, 19: 112, 20: 196}
# 23
# ...

# %%
l = [1] + [2]
l
# Out:
# [1, 2]

# %%
check = ['####LL####', '##LL#L#L###', 'L#####L#L#L#']
d = " ".join(check).count('#')
d
#sum(x.count('#') for x in check)
# Out:
# 23

# %%
l = []
for x in check:
    add = sum(('#' in y for y in x))
    #sum.append(add)

# %%
l = [1, 2, 3, 4, 5, 6, 7]
conditions = [2 in l, 9 in l]
if conditions[0] or conditions[1]:
    print('yes')
else:
    print('no')
# Out:
# yes

# %%
seat, j, i = '#', 1, 1
conditions = [seat == '#' and seat[j-1] == '#' or '.'
                or seat[j+1] =='#' or '.'
                or seatrow[i-1][j] == '#' or '.'
                or seatrow[i-1][j-1] == '#' or '.'
                or seatrow[i-1][j+1] == '#' or '.'
                or seatrow[i+1][j] == '#' or '.'
                or seatrow[i+1][j-1] == '#' or '.'
                or seatrow[i+1][j+1] == '#' or '.', 
                seat == 'L' and seat[j-1] == 'L' or '.'
                and seat[j+1] =='L' or '.'
                and seatrow[i-1][j] == 'L' or '.'
                and seatrow[i-1][j-1] == 'L' or '.'
                and seatrow[i-1][j+1] == 'L' or '.'
                and seatrow[i+1][j] == 'L' or '.'
                and seatrow[i+1][j-1] == 'L' or '.'
                and seatrow[i+1][j+1] == 'L' or '.']
# Out:
# -------------------------------------------------------------------------
# IndexError                              Traceback (most recent call last)
# <ipython-input-34-caa26ae15014> in <module>
#       9                 or seatrow[i+1][j+1] == '#' or '.',
#      10                 seat == 'L' and seat[j-1] == 'L' or '.'
# ---> 11                 and seat[j+1] =='L' or '.'
#      12                 and seatrow[i-1][j] == 'L' or '.'
#      13                 and seatrow[i-1][j-1] == 'L' or '.'
#
# IndexError: string index out of range

# %%
l = ['######################.########.##############.#####.#####.####.####.##########.######.#####',
     '######################.########.##############.#####.#####.####.####.##########.######.#####',
     '######################.########.##############.#####.#####.####.####.##########.######.#####', '#']

# %%
print(l[0][1].replace("#", "L")
# Out:
#   File "<ipython-input-40-4452b40b2341>", line 1
#     print(l[0][1].replace("#", "L")
#                                    ^
# SyntaxError: unexpected EOF while parsing

# %%
l.split()
# Out:
# -------------------------------------------------------------------------
# AttributeError                          Traceback (most recent call last)
# <ipython-input-41-00da2dd6f77a> in <module>
# ----> 1 l.split()
#
# AttributeError: 'list' object has no attribute 'split'

# %%
l[0].split()
# Out:
# ['######################.########.##############.#####.#####.####.####.##########.######.#####']

# %%
sum(x.count('#') for x in l)
# Out:
# 250

# %%
l = [['L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', '.', '.', 'L', 'L', 'L', '.', 'L', '.', 'L', 'L', 'L', 'L', 'L'], ['L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L']]

# %%
for line in l:
    print(line)
    break
# Out:
# ['.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', '.', 'L', 'L', 'L', 'L', 'L', '.', '.', 'L', 'L', 'L', '.', 'L', '.', 'L', 'L', 'L', 'L', 'L']

# %%
p = [0,1]
p.append(3)
p

elif (seat == 'L' and seatrow[j-1] == 'L' or '.'
        and seatrow[j+1] == 'L' or '.'
        and seatrow[j] != 'N'):
            print('This is an L')
# Out:
# [0, 1, 3]

# %%
for i, seatrow in enumerate(l):
    for j, seat in enumerate(seatrow):
        if all(seat == 'L' and seat != 'N'):
            print('yes')
# Out:
# -------------------------------------------------------------------------
# TypeError                               Traceback (most recent call last)
# <ipython-input-83-a5958863b4d7> in <module>
#       1 for i, seatrow in enumerate(l):
#       2     for j, seat in enumerate(seatrow):
# ----> 3         if all(seat == 'L' and seat != 'N'):
#       4             print('yes')
#
# TypeError: 'bool' object is not iterable

# %%
elif seat == 'L' and all(seatrow[j-1] == 'L' or '.'
                and seat[j+1] =='L' or '.'
                and seatrow[i-1][j] == 'L' or '.'
                and seatrow[i-1][j-1] == 'L' or '.'
                and seatrow[i-1][j+1] == 'L' or '.'
                and seatrow[i+1][j] == 'L' or '.'
                and seatrow[i+1][j-1] == 'L' or '.'
                and seatrow[i+1][j+1] == 'L' or '.')
# Out:
#   File "<ipython-input-81-24f4fb9aefd0>", line 1
#     elif seat == 'L' and all(seatrow[j-1] == 'L' or '.'
#        ^
# SyntaxError: invalid syntax

# %%
all([seatrow[j-1] == 'L' or '.', seat[j+1] =='L' or '.'])
# Out:
# -------------------------------------------------------------------------
# IndexError                              Traceback (most recent call last)
# <ipython-input-84-ae4caad3a271> in <module>
# ----> 1 all([seatrow[j-1] == 'L' or '.', seat[j+1] =='L' or '.'])
#
# IndexError: string index out of range

# %%
l = [x for x in range(10)]

# %%
for x in l:
    if x > 2:
        print('sgaerv')
# Out:
# sgaerv
# sgaerv
# sgaerv
# sgaerv
# sgaerv
# sgaerv
# sgaerv

# %%
print("""
Line1
Line2
""")
# Out:
# Line1
# Line2

# %%
3%4
# Out:
# 3

# %%
13%37
# Out:
# 13

# %%
from collections import defaultdict

s = [('red', 1), ('blue', 2), ('red', 3), ('blue', 4), ('red', 1), ('blue', 4)]

d = defaultdict(set)

for k, v in s:

    d[k].add(v)

d
# Out:
# defaultdict(set, {'red': {1, 3}, 'blue': {2, 4}})

# %%
s = [('red', 1), ('blue', 2), ('red', 3), ('blue', 4), ('red', 1), ('blue', 4)]

d = {}

for k, v in s:

    d[k].add(v)
    break

d
# Out:
# -------------------------------------------------------------------------
# KeyError                                Traceback (most recent call last)
# <ipython-input-108-2a70e74b2165> in <module>
#       5 for k, v in s:
#       6
# ----> 7     d[k].add(v)
#       8     break
#       9
#
# KeyError: 'red'

# %%
print(bin(1), bin(2), bin(1 << 1), bin(17), bin(17 >> 1))
# Out:
# 0b1 0b10 0b10 0b10001 0b1000

# %%
n1 = 1
n2 = 2

# %%
print(n1 |= n2)
# Out:
#   File "<ipython-input-124-049acce13a7b>", line 1
#     print(n1 |= n2)
#               ^
# SyntaxError: invalid syntax

# %%
def f(x):
    for i in range(36):
        if msk[36 - 1 - i] == '1':
            x |= (1 << i)
            print(x)

        if msk[36 - 1 - i] == '0':
            x &= (~(1 << i))
            print(x)
    return x

msk = '11100010111110X010100001X00000011XXX'

# %%
f(1053547115)
# Out:
# 1053547115
# 1053547131
# 1053547099
# 1053547035
# 1053547035
# 1053547035
# 1053546523
# 1053546523
# 1053546523
# 1053546523
# 1053530139
# 1053497371
# 1053431835
# 1053431835
# 1053431835
# 1053431835
# 1053431835
# 1049237531
# 1049237531
# 1066014747
# 1066014747
# 1066014747
# 1066014747
# 797579291
# 797579291
# 797579291
# 797579291
# 797579291
# 9387513883
# 26567383067
# 60927121435
# 60927121435

# %%
f(10509)
# Out:
# 60927121437

# %%
1 |= (1 << 35)
# Out:
#   File "<ipython-input-136-d6f4c4123323>", line 1
#     1 |= (1 << 35)
#                   ^
# SyntaxError: can't assign to literal
